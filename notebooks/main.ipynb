# %% [markdown]
# # Données de Ratings

# %%
import sys
sys.path.insert(0, '..')
import importlib

# Si vous modifiez le fichier preprocessing, n'oubliez pas d'activer la ligne suivante
#importlib.reload(src.preprocessing)
from src.preprocessing import prepare_corporate_ratings, annualize_and_fill_ratings, create_quarterly_rating_transitions, truncating_data

DATA_PATH = "../data/credit_ratings/data_rating_corporate.xlsx"

df_initial = prepare_corporate_ratings(DATA_PATH)

# 2. Appeler la fonction de traitement ANNUEL
# Le résultat est stocké dans l'objet 'data_rating_yearly'
data_rating_yearly = annualize_and_fill_ratings(df_initial)

# 3. Appeler la fonction de traitement TRIMESTRIEL
# Le résultat est stocké dans l'objet 'data_rating_quarterly'
data_rating_quarterly = create_quarterly_rating_transitions(df_initial)

# 4. On tronque la période pour garantir une quantité suffisante de données.
data_rating_quarterly_updated_date = truncating_data(data_rating_quarterly, date_begin="2011-01-01", date_finish="2022-12-31")
data_rating_yearly_updated_date = truncating_data(data_rating_yearly, date_begin="2011-01-01", date_finish="2022-12-31")
# Out:
# ✅ Données chargées et préparées avec succès.

# %% [markdown]
# Les différents secteurs sont représentés ci-dessous :

# %%
data_rating_quarterly_updated_date["nace"].unique()
# Out:
# <StringArray>
# ['RU', 'JZ', 'OQ', 'C5', 'KZ', 'HZ', 'GZ', 'MN', 'C1', 'FZ', 'C3', 'LZ', 'CH',
#  'C4', 'BZ', 'IZ', 'AZ', 'C2']
# Length: 18, dtype: str

# %%
#Graphique de la distribution des ratings attribués
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
df_initial['rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Distribution des Ratings Attribués')
# Out:
# Text(0.5, 1.0, 'Distribution des Ratings Attribués')

# %%
# Ta ligne optimisée avec la petite touche finale pour le look "Stress Test"
df_initial.groupby(['year', 'rating']).size().unstack(fill_value=0).plot(
    kind='line', 
    stacked=False, 
    figsize=(12, 6),
    marker=None # Enlève les points si tu veux des lignes lisses comme sur l'image
)

# Pour mettre la légende en bas comme sur ton modèle
plt.legend(title="Rating category", loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, frameon=False)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
print(df_initial[df_initial['rating_agency_name'] == "Japan Credit Rating Agency,Ltd"]['rating'].unique())
# Out:
# <StringArray>
# []
# Length: 0, dtype: str

# %%
# Ta ligne optimisée avec la petite touche finale pour le look "Stress Test"
df_initial.groupby(['year', 'rating']).size().unstack(fill_value=0).plot(
    kind='line', 
    stacked=False, 
    figsize=(12, 6),
    marker=None # Enlève les points si tu veux des lignes lisses comme sur l'image
)

# Pour mettre la légende en bas comme sur ton modèle
plt.legend(title="Rating category", loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, frameon=False)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
#overall distribution  of rating in the dataset histogram in percentage

# 1. On définit l'ordre logique (Master scale)
ordre_metier = ['AAA', 'AA', 'A', 'BBB', 'BB', 'B','CCC', 'C', 'D']

# 2. Calcul des pourcentages
df_pct = df_initial['rating'].value_counts(normalize=True) * 100

# 3. ON FORCE L'ORDRE (C'est ici que ça se joue)
# On utilise .reindex pour dire à Pandas : "Oublie l'alphabet, utilise ma liste"
df_pct = df_pct.reindex(ordre_metier).dropna() # dropna() enlève les catégories de la liste qui ne seraient pas dans tes données
# 2. Tracé du graphique
ax = df_pct.plot(kind='bar', figsize=(10, 6), color='steelblue', edgecolor='black')

# 3. Cosmétique "Expert"
plt.title('Répartition Globale des Ratings (en %)', fontsize=14, fontweight='bold', pad=15)
plt.ylabel('Pourcentage du Portefeuille (%)', fontsize=12)
plt.xlabel('Classe de Risque', fontsize=12)
plt.xticks(rotation=0) # Pour garder les labels horizontaux et lisibles

# Ajout des étiquettes de pourcentage au-dessus de chaque barre
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}%', 
                (p.get_x() + p.get_width() / 2., p.get_height() + 0.5), 
                ha='center', va='bottom', fontsize=10, fontweight='bold')

# On ajuste la limite haute de l'axe Y pour laisser de la place aux étiquettes
plt.ylim(0, df_pct.max() + 5)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#Distribution of rating categorie by sectors
df_sectors = df_initial.groupby(['nace', 'rating']).size().unstack(fill_value=0)
df_sectors_pct = df_sectors.div(df_sectors.sum(axis=1), axis=0) * 100
# On réindexe pour forcer l'ordre des ratings
df_sectors_pct = df_sectors_pct.reindex(columns=ordre_metier).fillna(0)

#on réalise un graphique en barres empilées pour chaque secteur
ax = df_sectors_pct.plot(kind='bar', stacked=True, figsize=(12, 8), colormap='tab20')
plt.title('Distribution des Ratings par Secteur (en %)', fontsize=14, fontweight='bold', pad=15)
plt.ylabel('Pourcentage du Secteur (%)', fontsize=12)
plt.xlabel('Secteur d\'Activité (NACE)', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title="Rating category", loc='upper center', bbox_to_anchor=(0.5
, -0.15), ncol=4, frameon=False)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#show the information
df_initial.head()
# Out:
#            rating_agency_name rating rating_action_date  \
# 0  Egan-Jones Ratings Company      B         2022-07-22
# 1  Egan-Jones Ratings Company      B         2023-07-21
# 2  Egan-Jones Ratings Company      B         2023-09-18
# 3               Fitch Ratings      B         2021-08-18
# 4               Fitch Ratings      C         2022-06-27
#
#   legal_entity_identifier           obligor_name year_month  year pays nace
# 0                     NaN  06 ENVIRONMENTAL, LLC 2022-07-01  2022  NaN   RU
# 1                     NaN  06 ENVIRONMENTAL, LLC 2023-07-01  2023  NaN   RU
# 2                     NaN  06 ENVIRONMENTAL, LLC 2023-09-01  2023  NaN   RU
# 3    549300ETSKJL315VDV79  11065220 Canada, Inc. 2021-08-01  2021  NaN   RU
# 4    549300ETSKJL315VDV79  11065220 Canada, Inc. 2022-06-01  2022  NaN   RU

# %%
#when there is not a lot of values on the feature "pays", create an other value "Other" for the values that are not in the top 10 of the feature "pays"
# 1. Calcule le Top 10 une seule fois (très rapide)
top_10_countries = df_initial['pays'].value_counts().nlargest(10).index
df_try = df_initial.copy()
# 2. Utilise .isin() avec .loc pour modifier les données en bloc mais si le pays n'est pas renseigné (NAN), écrire 'unspecified'
df_try.loc[df_try['pays'].isna(), 'pays'] = 'unspecified'
# Si le pays n'est PAS dans le top 10, on met 'Other'
df_try.loc[~df_try['pays'].isin(top_10_countries), 'pays'] = 'Other'
#number of distincts firm by country histogram horizontal
df_country = df_try.groupby('pays')['obligor_name'].nunique()
df_country.sort_values().plot(kind='barh', figsize=(12, 8), color='steelblue', edgecolor='black')
plt.title('Number of Distinct Firms by Country', fontsize=14, fontweight='bold', pad=15)
plt.ylabel('Country', fontsize=12)
plt.xlabel('Number of Firms', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
#Afficher les valeurs à côté de chaque barre
for index, value in enumerate(df_country.sort_values()):
    plt.text(value, index, str(value), va='center', fontsize=10, fontweight='bold')
plt.show()

# %%
# Si vous modifiez le fichier 'preprocessing', n'oubliez pas d'activer la ligne suivante
# importlib.reload(src.preprocessing)
from src.preprocessing import SectorPortfolio

all_sectors = SectorPortfolio.create_from_processed_data(
    name="all",
    sectors=['RU', 'JZ', 'OQ', 'C5', 'KZ', 'HZ', 'GZ', 'MN', 'C1', 'FZ', 'C3','LZ', 'CH', 'C4', 'BZ', 'IZ', 'AZ', 'C2'], # Liste de tous les secteurs
    annual_data=data_rating_yearly_updated_date,
    quarterly_data=data_rating_quarterly_updated_date
)

industrie_portfolio = SectorPortfolio.create_from_processed_data(
    name="industrie",
    sectors=['C1','C2','C3','C4','C5'], # Secteurs industriels spécifiques
    annual_data=data_rating_yearly_updated_date,
    quarterly_data=data_rating_quarterly_updated_date
)

# Créez autant de portefeuilles sectoriels que vous le souhaitez

# Ensuite, vous pouvez appeler les différents objets :
print("✅ Portefeuille créé :", industrie_portfolio.name)
print("📊 Secteurs inclus :", industrie_portfolio.sectors)
# print("🔹 Données annuelles :", industrie_portfolio.annual_data)
# print("🔹 Données trimestrielles :", industrie_portfolio.quarterly_data)
# Out:
# ✅ Portefeuille créé : industrie
# 📊 Secteurs inclus : ['C1', 'C2', 'C3', 'C4', 'C5']

# %%
# Si vous modifiez le fichier 'merton_homo', n'oubliez pas d'activer la ligne suivante
# importlib.reload(src.merton_homo)
from src.merton_homo import MertonHomogeneous

merton_industry = MertonHomogeneous(all_sectors)
zt_industry = merton_industry.compute()

# Affichage des résultats
print("PD TTC homogène :", round(merton_industry.p_ttc * 100, 2), "%")
print("Barrière :", merton_industry.barriers)
print("Rho :", round(merton_industry.rho * 100, 2), "%")

# Fonctions de visualisation
zt_industry.plotting_zt()
zt_industry.plot_pred_obs()
zt_industry.mse()
# Out:
# PD TTC homogène : 0.8 %
# Barrière : -2.4073294034219246
# Rho : 20.03 %
# np.float64(9.702481392755877e-36)

# %%
# Si vous modifiez le fichier 'merton', n'oubliez pas d'activer la ligne suivante
# importlib.reload(src.merton)

from src.merton import Merton

merton_industrie_portfolio = Merton(all_sectors)
zt = merton_industrie_portfolio.compute()

# Affichage des résultats
print("PD TTC :\n", round(merton_industrie_portfolio.pd_ttc * 100, 4))
print("Barrière :\n", merton_industrie_portfolio.barrier)
print("Rho :\n", round(merton_industrie_portfolio.rho * 100, 2))

# Fonctions de visualisation et calcul de l'erreur
zt.plotting_zt()
zt.plot_transitions()
mse_global, mse_rating = zt.mse()

print("mse_global : ", mse_global, "\nmse_rating : \n", mse_rating)
# Out:
# PD TTC :
#  rating
# AAA    0.0359
# A      0.0461
# BBB    0.0602
# BB     0.2218
# B      0.9007
# C      8.8882
# dtype: float64
# Barrière :
#  rating
# AAA   -3.382364
# A     -3.313358
# BBB   -3.237985
# BB    -2.845313
# B     -2.365333
# C     -1.347671
# dtype: float64
# Rho :
#  rating
# AAA    23.79
# A      23.73
# BBB    23.64
# BB     22.74
# B      19.65
# C      12.14
# dtype: float64
# mse_global :  6.4990234464297046e-06
# mse_rating :
#  rating
# A      4.680392e-08
# AAA    7.925211e-09
# B      3.462245e-05
# BB     2.565812e-06
# BBB    6.654942e-07
# C      1.085655e-06
# dtype: float64

# %%
# Si vous modifiez le fichier 'creditmetrics', n'oubliez pas d'activer la ligne suivante
# importlib.reload(src.creditmetrics)
from src.creditmetrics import CreditMetrics

cm_industrie_portfolio = CreditMetrics(all_sectors)
zt = cm_industrie_portfolio.compute()

# Affichage des résultats
print("p_ij TTC :\n", round(cm_industrie_portfolio.migration_ttc * 100, 2))
print("Barrière :\n", cm_industrie_portfolio.barrier_matrix)
print("Rho :\n", round(cm_industrie_portfolio.rho * 100, 2))
# Pour voir les valeurs directement, vous pouvez afficher les objets 'migration_ttc', 'barrier_matrix' et 'rho'

# Fonctions de visualisation et calcul de l'erreur
# Tracé de la série temporelle Zt
zt.plotting_zt()
mse_global, mse_matrix = zt.mse()

# Calcule la MSE entre les probabilités de transition estimées (avec le Z estimé) 
# et les probabilités observées.
print("mse_global : ", mse_global, "\nmse_matrix : \n", mse_matrix)

# Affiche les probabilités de transition estimées et observées pour une paire de notations spécifique.
zt.plot_transitions([["BBB", "B"], ["C", "D"]])
# Out:
# p_ij TTC :
#  next_rating    AAA      A    BBB     BB      B      C     D
# rating
# AAA          84.80   8.30   1.69   2.37   2.41   0.40  0.04
# A             2.50  84.04   8.03   2.41   2.70   0.28  0.05
# BBB           0.36   6.01  80.79   7.28   4.87   0.64  0.06
# BB            0.40   1.70   7.90  74.69  13.56   1.53  0.22
# B             0.47   1.63   3.53   8.40  77.49   7.59  0.90
# C             0.52   2.35   4.12   6.72  25.41  51.99  8.89
# Barrière :
#  next_rating       AAA         A       BBB        BB         B         C  \
# rating
# AAA               inf -1.027918 -1.483353 -1.624805 -1.905052 -2.626619
# A                 inf  1.960280 -1.104967 -1.604556 -1.877337 -2.723839
# BBB          8.209536  2.686401  1.524707 -1.133657 -1.592457 -2.459573
# BB                inf  2.649885  2.032855  1.281130 -1.023360 -2.108344
# B                 inf  2.598862  2.034345  1.587183  1.079230 -1.373021
# C                 inf  2.562744  1.900084  1.476201  1.093254  0.276025
#
# next_rating         D
# rating
# AAA         -3.382364
# A           -3.313358
# BBB         -3.237985
# BB          -2.845313
# B           -2.365333
# C           -1.347671
# Rho :
#  rating
# AAA    23.79
# A      23.73
# BBB    23.64
# BB     22.74
# B      19.65
# C      12.14
# Name: D, dtype: float64
# mse_global :  0.002444634418738786
# mse_matrix :
#  next_rating         A       AAA         B        BB       BBB         C  \
# rating
# A            0.002434  0.000675  0.000419  0.000285  0.001202  0.000003
# AAA          0.002259  0.004395  0.000338  0.000355  0.000170  0.000009
# B            0.000073  0.000002  0.002834  0.000732  0.000422  0.000666
# BB           0.000040  0.000001  0.002385  0.003845  0.000585  0.000074
# BBB          0.001518  0.000005  0.001357  0.001077  0.004166  0.000022
# C            0.000288  0.000009  0.009092  0.002639  0.001057  0.054432
#
# next_rating             D
# rating
# A            6.645167e-08
# AAA          2.100504e-08
# B            2.787298e-05
# BB           2.009215e-06
# BBB          6.545961e-07
# C            2.778361e-03

# %% [markdown]
# # Variables historiques et NGFS

# %%
import sys
sys.path.insert(0, '..')

from src.other_data import data_management

DATA_PATH_HISTO = "../data/macro_data/Données_macro_hist_v2.xlsx"

data_hist = data_management(DATA_PATH_HISTO)
data_hist
# Out:
# var_id      EU - Central bank Intervention rate (policy interest rate)  \
# 2010-01-01                                           1.000000
# 2010-04-01                                           1.000000
# 2010-07-01                                           1.000000
# 2010-10-01                                           1.000000
# 2011-01-01                                           1.000000
# ...                                                       ...
# 2024-01-01                                           4.500000
# 2024-04-01                                           4.416667
# 2024-07-01                                           4.000000
# 2024-10-01                                           3.166667
# 2025-01-01                                           2.750000
#
# var_id      EU - Effective exchange rate  EU - GDP Growth Rate  \
# 2010-01-01                    104.322425              0.357380
# 2010-04-01                     98.473032              0.999191
# 2010-07-01                     98.062300              0.478303
# 2010-10-01                    100.066390              0.612048
# 2011-01-01                     99.556516              0.961402
# ...                                  ...                   ...
# 2024-01-01                    111.535023              0.300445
# 2024-04-01                    111.963459              0.298976
# 2024-07-01                    112.816790              0.386361
# 2024-10-01                    111.581053              0.400308
# 2025-01-01                    111.018067              0.551445
#
# var_id      EU - Long term interest rate  EU - Unemployment rate  \
# 2010-01-01                      4.064402               10.100000
# 2010-04-01                      3.841593               10.133330
# 2010-07-01                      3.514643               10.033330
# 2010-10-01                      3.707037               10.033330
# 2011-01-01                      4.302840                9.933333
# ...                                  ...                     ...
# 2024-01-01                      2.961033                6.066667
# 2024-04-01                      3.120024                6.000000
# 2024-07-01                      2.951025                5.933333
# 2024-10-01                      2.869136                5.833333
# 2025-01-01                      3.130128                5.900000
#
# var_id      US - Central bank Intervention rate (policy interest rate)  \
# 2010-01-01                                           0.125000
# 2010-04-01                                           0.125000
# 2010-07-01                                           0.125000
# 2010-10-01                                           0.125000
# 2011-01-01                                           0.125000
# ...                                                       ...
# 2024-01-01                                           5.375000
# 2024-04-01                                           5.375000
# 2024-07-01                                           5.208333
# 2024-10-01                                           4.625000
# 2025-01-01                                           4.375000
#
# var_id      US - Effective exchange rate  US - Equity prices  \
# 2010-01-01                     87.527759           46.875171
# 2010-04-01                     88.939386           41.314746
# 2010-07-01                     87.717124           45.743602
# 2010-10-01                     84.067552           50.410959
# 2011-01-01                     82.986452           53.144269
# ...                                  ...                 ...
# 2024-01-01                    111.504760          210.614185
# 2024-04-01                    113.708275          218.876649
# 2024-07-01                    113.095423          230.981949
# 2024-10-01                    115.663895          235.757927
# 2025-01-01                    117.819208          223.705139
#
# var_id      US - GDP Growth Rate  US - House prices (residential)  \
# 2010-01-01              0.484501                        86.640269
# 2010-04-01              0.967586                        86.086237
# 2010-07-01              0.771085                        84.491229
# 2010-10-01              0.525110                        83.119199
# 2011-01-01             -0.237205                        80.612840
# ...                          ...                              ...
# 2024-01-01              0.404802                       141.105711
# 2024-04-01              0.738980                       141.644220
# 2024-07-01              0.759510                       142.303761
# 2024-10-01              0.607065                       143.434180
# 2025-01-01             -0.060750                       143.191939
#
# var_id      US - Inflation rate  US - Long term interest rate  US - Oil price  \
# 2010-01-01             2.360525                      3.716667       76.674837
# 2010-04-01             1.767765                      3.490000       78.845036
# 2010-07-01             1.175609                      2.786667       76.675000
# 2010-10-01             1.270248                      2.863333       87.033160
# 2011-01-01             2.141127                      3.460000      105.369424
# ...                         ...                           ...             ...
# 2024-01-01             3.240480                      4.160000       81.955714
# 2024-04-01             3.199263                      4.443333       84.981986
# 2024-07-01             2.622039                      3.946667       78.708317
# 2024-10-01             2.745114                      4.283333       74.000940
# 2025-01-01             2.737586                      4.453333       75.042781
#
# var_id      US - Unemployment rate
# 2010-01-01                9.833333
# 2010-04-01                9.633333
# 2010-07-01                9.466666
# 2010-10-01                9.500000
# 2011-01-01                9.033334
# ...                            ...
# 2024-01-01                3.833333
# 2024-04-01                4.000000
# 2024-07-01                4.166667
# 2024-10-01                4.133333
# 2025-01-01                4.100000
#
# [61 rows x 14 columns]

# %%
import sys
sys.path.insert(0, '..')

from src.other_data import get_specific_data, reverse_ngfs_transformation, trimestrialiser_par_interpolation

from constant import MODELS, COUNTRIES_IMPORT

DATA_PATH_NGFS = "../data/ngfs_data/NiGEM_data.xlsx"

data_input = get_specific_data(DATA_PATH_NGFS, MODELS, COUNTRIES_IMPORT)

data_input_tr = reverse_ngfs_transformation(data_input)

data_input_tr_tri = trimestrialiser_par_interpolation(data_input_tr)

# %% [markdown]
# # Importation TES

# %%
import sys
sys.path.insert(0, '..')

import src.import_tes
# Si vous modifiez le fichier 'import_tes', n'oubliez pas d'activer la ligne suivante
importlib.reload(src.import_tes)

from src.import_tes import importing_tes

path = '../data/international_TES'

dfs, df_pays, descp_nace = importing_tes(path) 

# dfs est un dictionnaire qui se lit dfs["20XX"] et qui contient le Tableau Entrées-Sorties (TES) pour l'année en question.
# df_pays contient tous les acronymes des pays.
# descp_nace contient les descriptions de la segmentation NACE 88 et NACE 17.
# Out:
# c:\Users\jeremy.martin_square\Desktop\Projet_ENSAI\PROJET_ESA_SRESS_TEST_SQUARE_MANAGEMENT\venv\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: ColItems!$A:$A.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# c:\Users\jeremy.martin_square\Desktop\Projet_ENSAI\PROJET_ESA_SRESS_TEST_SQUARE_MANAGEMENT\venv\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: RowItems!$A:$A.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")

# %% [markdown]
# Ici, deux options s'offrent à vous. Je vous propose une fonction qui agrège les TES pour tous les pays. Vous pourrez sinon filtrer en amont sur un pays, puis appliquer la fonction qui enlèvera la mention du pays. Vous pourrez vous aider du df_pays qui mentionne les acronymes des différents pays.

# %%
# Si vous modifiez le fichier 'import_tes', n'oubliez pas d'activer la ligne suivante
import src.import_tes  
importlib.reload(src.import_tes)
from src.import_tes import leaving_countries, filtering_country

df_no_countries = leaving_countries(dfs)

df_USA = filtering_country(dfs, "USA")

# %% [markdown]
# La prochaine fonction permet de faire basculer du NACE 88 au NACE 17

# %%
# Si vous modifiez le fichier import_tes n'oubliez pas d'activer la ligne suivante
# importlib.reload(src.import_tes)
from src.import_tes import changing_nace_framework

df_nace17 = changing_nace_framework(df_USA, descp_nace)
df_nace17
# Out:
# {'2011':             AZ          BZ           C1           C2          C3           C4  \
#  AZ  59741.0192    201.9627  179683.2755      20.7081      1.9319       1.2871
#  BZ   5967.4198  99268.2512   13308.3431  223323.7502   6017.6662    4753.0092
#  C1  31829.1175    136.6936  133392.0835     439.6411    260.8318     211.7362
#  C2  12417.5844  39913.1094    4274.6797   17658.3518   3565.0322    1415.2429
#  C3   4254.3465  11809.6716    4258.3970     308.4537  57965.3979   27726.8145
#  C4    875.9513   2478.9546    1778.7030      93.8016  10785.1424  117348.9096
#  C5  27753.2301  16202.8302   45803.6612   12603.6213  28842.7378   35513.8645
#  CH   1727.1573  12198.6444   14667.0834     479.4013  73394.8689   76434.2335
#  FZ   1530.2046  11194.2921    1545.7845    5641.4273   1133.3962     847.9223
#  GZ  43519.9048  28933.1227  120760.1868   12889.4406  57568.2270   67107.5988
#  HZ   8060.5961  21137.8361   21748.9494   41315.2210   9575.1203    8227.6284
#  IZ    560.0663   3536.3241    1103.7642     451.8300    985.2715     459.3245
#  JZ   1437.6593  11491.5227    4380.7039     947.1862   8734.5008    3786.9137
#  KZ   4852.2314  25309.1412    6118.7921    6047.7066   8030.1447    5248.1568
#  LZ  11570.7103   5490.1008    2117.5150     177.7200   4179.0175    3657.2683
#  MN   5989.9017  76359.5776   30415.6152    6620.0537  56503.3742   33952.2043
#  OQ   4452.0508  23558.8798    6318.1891    2760.0350   2804.6753    2134.3444
#  RU    437.2952   1680.9046     790.3343     177.2103    489.7332     323.4746
#
#               C5           CH           FZ           GZ           HZ  \
#  AZ   25140.7843       3.2868    2030.9916    2960.8771      59.7545
#  BZ   51577.1661   33893.3594   14831.4802   44133.6682   20700.0803
#  C1    8294.1586     216.8449     329.7686    6699.4209     711.4021
#  C2   47230.9885    5481.2466   28432.2950    9819.4874   93558.0120
#  C3   18859.0499    9777.3082   35762.6427   10205.8912    2497.4181
#  C4    5026.2384    1780.1143    3081.5930   17240.9052    9825.2343
#  C5  366767.8615   21434.9698  105966.9647   54694.9905   10927.8438
#  CH   37920.2651  169725.1113   53273.0355    8292.9835    5589.0966
#  FZ    4382.6292    1948.1169     201.6685    5660.0644    5482.1921
#  GZ  183396.2152   40482.8150   78305.4892   94551.3159   45719.4873
#  HZ   29894.5352   13822.2264   15680.4127  133462.0926  117159.1695
#  IZ    3051.3896    1432.9352     663.2444    8937.8435   11222.7340
#  JZ   15165.4199    5146.7917   10363.1667   90585.6186   11672.2690
#  KZ   13722.7464    8475.5568    8520.1187   70179.2794   39714.2008
#  LZ    9072.0888    3437.7871    8233.5991  128598.7304   19945.1407
#  MN   85171.2986   34080.8298   50759.7443  301198.1855   68930.3486
#  OQ   15582.7818    4846.5612    4185.0796   31796.5922   11569.8204
#  RU    1811.0201     757.1910    1328.2588   12066.3334    3745.3259
#
#              IZ           JZ           KZ           LZ           MN  \
#  AZ   1375.7369     160.4190      25.0183      80.9416    1516.4610
#  BZ  23989.1072    5518.8236    6985.4918   50763.3623   18824.2154
#  C1  41307.3207     178.0799      23.6821      54.4840    2370.5871
#  C2   4415.8958    2401.7194   11028.7461    3574.6207    9938.8865
#  C3   1429.3563   18683.4742    1052.0342     579.8220   14616.3737
#  C4    425.1238    1426.8949      97.6104     138.0569    5574.8879
#  C5  16794.0724   28259.8685    9878.8860   11528.6587   48555.3311
#  CH   2459.0778   10491.6412     777.6778    1766.7426    8681.6978
#  FZ   2335.9157    2730.8601    5821.0037   94792.5832    1994.6553
#  GZ  33406.0708   38577.0157   12701.8716   19258.5320   52821.4490
#  HZ  10504.4858   22008.3894   24189.3433    7804.2016   41843.6903
#  IZ   7880.2123   12703.9224   17549.9248   15545.5435   32524.6559
#  JZ  22151.0880  204787.6174   61700.6751   14595.1149  120840.9874
#  KZ  12042.4577   19531.7180  483497.4529  130466.2818  104415.8195
#  LZ  40762.5333   28321.6034   59549.6896  109953.4850   81970.1304
#  MN  93658.7818  193818.6374  173835.0861  119744.1274  334553.6703
#  OQ  10947.4092   13589.0279   22862.7162   22056.7173   24460.1402
#  RU   4532.0278   21924.1752    7445.5837    4266.8590   15702.8067
#
#               OQ          RU
#  AZ    4195.0271    530.8587
#  BZ   76788.0758   8748.9094
#  C1   51900.4010   4304.0481
#  C2  127305.1677   4392.1651
#  C3   23091.0755   3055.7751
#  C4   29685.2508    848.9353
#  C5  142471.4615  12103.2599
#  CH   15504.2090   2054.6524
#  FZ   73539.6776   4798.8628
#  GZ  167704.5552  14040.3391
#  HZ   80761.0541   8545.4441
#  IZ   43500.0313   4035.5501
#  JZ  177671.0943  19227.6246
#  KZ  132190.7486  27148.3598
#  LZ  179826.9217  49038.1635
#  MN  362954.4302  47530.7320
#  OQ  114916.3565  11656.9587
#  RU   25614.2370  16693.8281  ,
#  '2012':             AZ          BZ           C1           C2          C3           C4  \
#  AZ  68651.6980    190.2355  190292.9107      19.9278      2.0228       1.3347
#  BZ   5813.9810  87986.3922   10281.6956  229937.0401   4890.2009    3692.9957
#  C1  34338.5024    158.5409  141701.0440     508.0537    276.1989     235.2462
#  C2  12445.8582  37090.0221    3963.1495   19114.3976   3841.6823    1238.0431
#  C3   3750.6638  12997.5248    4065.3875     214.9456  57764.8659   29935.9151
#  C4    654.8797   2167.7236    1721.6055      32.6229  12092.9203  128995.4846
#  C5  30155.1765  17145.8506   44926.3365   12063.8531  29772.6186   34907.5888
#  CH   1731.9226  12207.3865   14831.1615     462.3282  73987.5933   78136.0936
#  FZ   1708.6192  12049.0592    1072.3090    6888.8258    829.3917     516.3952
#  GZ  48750.8196  29288.7302  131299.2282   13692.4803  61228.6877   74351.0898
#  HZ   9326.9621  21390.8290   23550.9221   42519.1048  11033.9425    9141.9134
#  IZ    666.9234   4023.4692    1324.3167     404.6197   1205.7286     658.2457
#  JZ   1609.6411  11714.1552    4527.3203    1016.5495   7621.5442    4571.3449
#  KZ   5534.9561  30528.5867    7994.5835    6014.8366  10092.8698    6949.1609
#  LZ  11641.4320   5943.9870    2074.0717     234.5212   4123.9648    4372.9895
#  MN   6898.5229  87215.9484   29256.5789    8771.4486  64189.7449   34425.8871
#  OQ   4362.4678  24136.1811    6184.8120    3713.5852   2634.8954    2040.7326
#  RU    426.8010   1550.4278     746.4791     179.9424    470.2723     327.9714
#
#               C5           CH           FZ           GZ           HZ  \
#  AZ   25014.2016       3.6609    1990.5830    3063.1129      85.5958
#  BZ   52585.8892   36373.5794   15019.9022   41718.7387   18422.8244
#  C1    8710.1656     229.3058     357.2611    6273.9836     804.8150
#  C2   42659.5184    5209.6449   27790.1553    9360.0578  107387.0869
#  C3   16824.4749    9362.9034   35962.0314    9405.6832    2778.4435
#  C4    3502.1742    1354.7427    1468.2764   18346.8867    9804.4227
#  C5  379130.7457   22011.2168  111637.6124   56645.0766   13216.1079
#  CH   37028.8230  156139.4879   54215.5464    6940.6120    5556.0176
#  FZ    3849.0629    1541.1837     194.4451    5407.7861    6465.0662
#  GZ  192685.3026   41481.6545   84451.1259   98896.6686   54461.2669
#  HZ   32787.2978   15408.8272   16878.6056  147729.9270  110915.8980
#  IZ    4086.7494    1871.4284     773.7588   10522.8012   11407.0113
#  JZ   16187.5686    5977.2078   11446.1959  100710.8208   11666.2785
#  KZ   17842.1386   11048.7872    9936.3887   80215.1974   44891.2343
#  LZ   10246.2398    4029.1012   10053.2446  146184.4785   23246.2747
#  MN   86891.3898   35110.5737   55926.7175  330706.9855   73216.2633
#  OQ   16502.1688    5033.6278    4448.1374   34417.9981   11555.9570
#  RU    1826.2627     741.7836    1348.5912   12310.2784    3961.9056
#
#               IZ           JZ           KZ           LZ           MN  \
#  AZ    1451.7839     208.8365      23.6744     106.9032    1667.0926
#  BZ   22497.3878    6771.3983    5999.4135   51940.8209   18163.5999
#  C1   42797.5224     203.0547      21.5513      94.6414    3657.3826
#  C2    3912.3155    2192.4886   10089.2002    4443.7050    9269.5048
#  C3    1338.5069   17688.2351     888.0227     682.3143   14095.2090
#  C4     360.0472    1312.5912      84.3816     107.8139    6383.1176
#  C5   17039.3895   30234.3186    9052.7759   14653.5598   50840.0220
#  CH    2569.4349   11072.0026     655.4505    2419.2674    8759.7288
#  FZ    2136.9255    2552.8596    5144.4366  101316.2946    1868.3066
#  GZ   35127.1980   39338.9670   12684.8810   16376.3604   57970.9636
#  HZ   10959.5802   23515.4311   19066.2033    8575.1390   40832.7908
#  IZ    9134.9625   14157.5417   16897.0659   18455.4053   33877.5002
#  JZ   24433.2635  222125.5842   59558.0085   17583.5869  123652.0065
#  KZ   14358.5297   21447.6916  534543.7764  160737.2807  108254.9686
#  LZ   46660.7335   36435.2669   55682.1712  105565.0926   93159.8591
#  MN  101849.4063  221111.9213  165978.9584  116975.0838  346387.1481
#  OQ   11442.4912   14483.6498   27921.6167   25063.8636   24123.0593
#  RU    4588.1046   21900.5103    6949.0413    4726.0135   15385.9841
#
#               OQ          RU
#  AZ    4051.1288    644.3254
#  BZ   71527.9463   8313.2943
#  C1   54273.4815   5226.5810
#  C2  125859.3024   3738.5170
#  C3   20625.7309   2976.0635
#  C4   28689.0218    762.0434
#  C5  139146.9858  12284.3907
#  CH   14462.2179   2335.5888
#  FZ   73976.2880   4014.1288
#  GZ  171714.4746  14631.4880
#  HZ   83298.8737   9365.4882
#  IZ   49886.4413   4732.9842
#  JZ  182913.8259  18684.5281
#  KZ  146565.0243  33314.2311
#  LZ  188511.1021  50380.0010
#  MN  376941.5532  48374.4013
#  OQ  117577.0468  12649.9196
#  RU   24694.5415  17127.4331  ,
#  '2013':             AZ          BZ           C1           C2          C3           C4  \
#  AZ  71088.0611    174.3340  209904.5236      19.8067      1.6902       1.3423
#  BZ   5131.0564  99488.0645   10033.2692  266652.6517   4503.0765    3896.7948
#  C1  35265.1802    191.5287  137416.0542     583.1873    293.0736     280.0948
#  C2  11920.8895  41577.0792    3581.1701   29471.5078   3369.3080    1196.7326
#  C3   3083.1916  13642.3493    4080.7978     262.3055  53609.9934   31411.3748
#  C4    571.2732   2258.7081    1809.9636      33.1472  12031.5991  147440.6730
#  C5  29996.2275  17853.6426   43504.1785   13407.3949  28349.0944   39070.3431
#  CH   1587.0978  13245.0140   14278.6414     488.8486  69215.2886   81019.1558
#  FZ   1730.1845  12458.5216     989.4969    7780.4129    735.0847     598.1022
#  GZ  50072.0578  32282.6451  135242.7800   17459.2788  59396.7554   82504.1574
#  HZ   9332.9484  23562.3118   24975.7100   42015.3890  10236.3639   10018.8947
#  IZ    616.3135   4296.6423    1294.4914     559.1033   1103.1276     657.2434
#  JZ   1509.5166  14578.1297    4634.6382    1285.7622   7391.5839    6087.1110
#  KZ   5761.0136  34616.6309    7539.9913    5385.2258   9318.2258    7227.5677
#  LZ   9916.4907   6926.9395    2291.8786     253.7873   4397.6354    4770.7187
#  MN   6356.4733  98253.5596   28034.9968   10698.6722  60898.9527   36477.0553
#  OQ   4175.8399  26781.7163    5989.0327    4186.1900   2431.0717    2119.5680
#  RU    398.8055   1620.1571     730.6965     219.5659    436.2723     422.5939
#
#               C5           CH           FZ           GZ           HZ  \
#  AZ   25664.1464       3.4157    2293.6638    3523.7367     115.9240
#  BZ   53128.4503   31033.0987   16221.2711   44082.5192   19643.4699
#  C1   10060.7411     264.2640     434.8375    6730.2978     822.7526
#  C2   37868.9658    5433.1046   28861.6418    9732.8825  111532.9568
#  C3   17824.7467   10071.2535   38668.9522    9803.8443    3160.6156
#  C4    4020.2004    1575.6077    1466.2557   18712.1117    9929.7286
#  C5  396391.5952   23536.7255  124062.9698   59126.8500   13785.9938
#  CH   38271.3977  158502.7875   56161.3941    7165.3353    5651.4908
#  FZ    3923.5636    1623.4202     196.5473    5526.2319    6573.2487
#  GZ  205945.8902   43689.5207   93927.7097  106114.3175   57087.6840
#  HZ   34018.4787   14162.3005   18612.3993  155102.3300  113575.2761
#  IZ    4379.0285    1847.4146     809.8358   11403.9730   11432.6463
#  JZ   17120.7411    6585.8863   12661.1812  107467.6485   11699.2930
#  KZ   18877.0928   11360.4237   10941.9676   83929.5647   46471.9623
#  LZ   11232.7367    4538.5985   11495.4479  160577.5330   24729.5804
#  MN   92895.8730   36829.0872   60353.1927  351256.7691   73703.2716
#  OQ   16934.7503    5224.2854    4916.8583   36118.7488   11747.8492
#  RU    1894.3209     759.4642    1365.6830   12928.6758    4059.0855
#
#               IZ           JZ           KZ           LZ           MN  \
#  AZ    1690.0629     203.0475      25.8348     120.7035    1882.2455
#  BZ   22647.7794    6256.1801    7421.7015   59211.0919   18520.1938
#  C1   48097.6361     218.5633      29.3958      91.2597    4430.4133
#  C2    3852.9163    2279.8840   13044.3223    4791.8826    9690.5889
#  C3    1330.7718   16647.3483    1147.8333     727.8434   14944.7799
#  C4     366.2061    1202.0790     105.2367      53.1470    6690.9191
#  C5   17343.6793   28320.6763   11262.2480   15723.0062   51386.5571
#  CH    2614.5833   10294.6852     758.5975    2462.6294    8725.8667
#  FZ    2060.4536    2501.7549    6235.9875  110312.3009    1842.6962
#  GZ   38544.7191   39606.4626   16228.8670   18824.0588   61202.5719
#  HZ   11009.0640   22576.5687   22685.9085    9543.2876   42609.9276
#  IZ    9812.1268   13985.1346   20638.6730   20550.8038   35752.5944
#  JZ   23027.1663  220607.9588   71017.3335   19348.8588  129491.2557
#  KZ   14444.6726   21132.9253  603661.3716  171926.2460  111318.3590
#  LZ   48665.1594   36400.6166   75316.0289  105279.9903   99570.7653
#  MN  102352.7005  215907.6481  201256.1410  128142.9326  358298.8125
#  OQ   11373.1891   14073.9841   26544.4738   25496.7849   25002.7724
#  RU    4682.6944   22102.0186    8427.4308    5178.5532   15747.4803
#
#               OQ          RU
#  AZ    4426.3594    717.8760
#  BZ   72244.5836   7998.0611
#  C1   59461.3231   5790.8630
#  C2  115922.2683   3672.2695
#  C3   19930.9561   3086.9831
#  C4   30452.9479    733.5573
#  C5  141944.1162  12603.9587
#  CH   14756.2207   2416.2278
#  FZ   77608.7296   3763.5057
#  GZ  176281.3518  15513.5957
#  HZ   81524.9841   9408.5207
#  IZ   49564.8816   4871.9878
#  JZ  175786.9272  18585.8848
#  KZ  147911.8335  31145.9794
#  LZ  194756.1216  54741.1790
#  MN  359761.1428  48166.1287
#  OQ  123713.8787  12892.1405
#  RU   24586.4843  17796.0975  ,
#  '2014':             AZ           BZ           C1           C2          C3  \
#  AZ  81688.5744     197.3294  210794.2869      12.9974      1.6755
#  BZ   6571.2102  125396.3038   10563.6868  271410.4608   4847.3954
#  C1  36098.0885     208.7131  137841.4012     268.8490    290.8343
#  C2  10547.8592   39083.0746    3191.0373   16917.5411   3806.9153
#  C3   3867.8366   15625.4735    4316.6475     157.2128  52369.9422
#  C4    733.8012    2736.6337    1894.3519      18.3118  12374.5019
#  C5  29399.3373   19541.2390   42823.4592    5194.2387  27665.3970
#  CH   1911.3337   14775.6310   14923.8553     218.4103  70331.0306
#  FZ   1852.4054   15893.7399     938.0106    6778.6766    701.6647
#  GZ  56112.3958   35464.0149  140517.3942   10766.0058  61094.6844
#  HZ  11108.7110   28449.9019   26905.2188   39631.9370  10467.2981
#  IZ    795.3936    5528.2340    1342.4157     402.3738   1175.7177
#  JZ   1849.9784   17668.2262    6615.9631     902.6955   7610.0855
#  KZ   6510.5720   42733.1251    8371.7650    4461.2235   9780.0713
#  LZ  10085.0694    7934.3949    2417.4423     226.3258   4664.2925
#  MN   8023.7878  115613.0077   29769.6879    5951.6143  58072.4729
#  OQ   4780.2724   30685.4172    6061.0638    3337.4494   2410.2750
#  RU    486.5852    1864.0516     835.2560     130.3628    434.5444
#
#               C4           C5           CH           FZ           GZ  \
#  AZ       1.3948   24431.5256       3.2017    2128.7519    3061.2826
#  BZ    4233.4647   59413.7428   31386.0974   18046.7138   48553.1805
#  C1     303.8865    9622.9113     265.3001     462.0898    6960.0257
#  C2    1211.2274   34793.4946    4482.9970   25747.3041    8687.9093
#  C3   34836.7100   17438.4725    9735.3678   41766.8858    9990.0654
#  C4  164685.2554    4145.2691    1623.3630    1644.8169   19626.5946
#  C5   42251.1617  382411.1060   23682.5617  133161.4332   61196.3933
#  CH   87610.2846   38239.8109  162231.2802   61019.9051    7444.8686
#  FZ     523.0704    3742.6029    1474.8569     205.2671    5393.3187
#  GZ   92889.8855  209774.1268   45157.0001  103173.4851  112710.5899
#  HZ   11746.2808   35921.1163   14947.8173   20989.5219  160980.9865
#  IZ     797.7580    4498.7271    1916.8084     899.7783   12438.3043
#  JZ    4817.1553   17830.8536    6743.2122   14404.5258  114760.5465
#  KZ    8726.3829   20474.6268   11766.1392   12614.3202   91130.5110
#  LZ    4892.3110   11290.3427    4534.4166   13798.1909  177474.2363
#  MN   36406.3319   96734.7023   37777.6383   70221.5622  374862.4404
#  OQ    2230.1756   16881.9505    5194.8492    5432.0669   37777.2545
#  RU     384.3807    1918.2146     760.8436    1543.4167   13457.2092
#
#               HZ           IZ           JZ           KZ           LZ  \
#  AZ     113.2822    1666.3361     197.6656      23.1273     133.9997
#  BZ   21650.5560   24893.3120    6710.9267    6919.6220   71683.1213
#  C1     827.8007   52639.2175     250.6819      26.2396     109.7942
#  C2  108899.2309    3523.1844    1832.8344    9355.3871    4627.9126
#  C3    3397.0715    1438.6258   17635.4527    1197.5596     940.2971
#  C4   11319.7883     406.0259    1539.4633     104.3175      84.3276
#  C5   14839.8611   17725.4720   30309.6066   10955.2013   16530.8314
#  CH    6392.0163    2729.6349   12051.3075     775.0329    3214.0371
#  FZ    7251.7301    2014.3528    2477.7427    6035.5705  116712.2405
#  GZ   60061.6914   42195.8499   44025.2423   15502.0653   20415.4597
#  HZ  126473.6692   11675.2711   23975.6140   23575.6221   11122.1333
#  IZ   10654.8810   10863.7373   15381.0105   20466.1439   23025.0522
#  JZ   12819.8588   24424.3504  236448.8093   73289.8826   21832.2335
#  KZ   51586.4343   15689.3759   23912.4356  627474.4788  185073.8193
#  LZ   27207.2183   53268.3154   40982.3646   78786.6633  110191.7347
#  MN   83341.6062  109857.9495  240882.1889  208974.2254  144738.9786
#  OQ   12231.4091   11859.4389   15343.4193   25516.0229   28102.9257
#  RU    4301.2261    4923.4940   25325.5746    8284.5619    5549.3531
#
#               MN           OQ          RU
#  AZ    1661.0971    4348.2027    644.3606
#  BZ   20759.5850   78835.2423   8318.7776
#  C1    4453.4623   63790.6882   6309.7963
#  C2    9311.9462   98871.8717   3264.1342
#  C3   15904.3388   20656.4295   3241.6592
#  C4    7708.6304   31372.5286    805.4150
#  C5   53718.6751  140895.9236  13177.6446
#  CH    9421.2461   14239.1713   2427.2756
#  FZ    1844.4443   78681.2709   3687.0168
#  GZ   66632.4917  179481.4617  16894.0841
#  HZ   47128.7664   83819.3053   9985.2355
#  IZ   40347.4764   52772.0610   5240.2656
#  JZ  144505.4793  175344.9819  19743.4556
#  KZ  122254.3141  166145.7602  34333.0881
#  LZ  107999.6619  205215.3607  59814.7294
#  MN  397577.3449  372974.5980  50934.7096
#  OQ   26387.6748  124179.4896  13357.4213
#  RU   16880.9480   25069.0107  18376.3619  ,
#  '2015':             AZ           BZ           C1           C2          C3  \
#  AZ  76112.2808     158.9329  188034.6741      12.4199      1.1100
#  BZ   5252.4827   89923.0799    8605.0132  156409.2586   4401.5465
#  C1  34649.5065     153.1361  135114.7691     253.2609    244.8807
#  C2   5842.2535   21431.1196    2387.3620   11277.4553   2556.9988
#  C3   3631.3435   13309.5710    4290.2524     122.9886  53481.8858
#  C4    660.4187    2497.0860    2104.8600      25.2452  11412.1774
#  C5  25850.8970   16597.9302   42957.9419    4454.8040  25338.1388
#  CH   1666.3024   10588.5390   13872.9113     247.7034  58234.2530
#  FZ   1669.9402   16499.9013     876.2145    7751.9101    651.1551
#  GZ  54497.0861   29306.6368  142264.5668    7565.0425  61989.6399
#  HZ  11780.3979   25490.7782   28474.1412   23671.9596   9689.0081
#  IZ    783.3436    5909.6475    1268.7326     223.6160   1009.7403
#  JZ   1743.1082   16253.9837    6045.0122     630.4817   7080.5562
#  KZ   6435.2030   39982.4194    7691.9421    2271.8122   8981.3356
#  LZ   8824.5391    8558.6068    2500.3448     224.1511   5172.8683
#  MN   7703.2969  104702.8189   30975.8453    5917.1432  53016.7531
#  OQ   4420.4355   30214.1228    5671.9959    2393.1918   2287.4933
#  RU    452.9898    1769.7511     810.2585      88.7329    400.0927
#
#               C4           C5           CH           FZ           GZ  \
#  AZ       1.0950   23043.2107       2.2503    2243.6237    2954.5477
#  BZ    3906.2310   48466.0992   25828.5584   19804.1084   45746.5432
#  C1     271.4680    8137.9707     220.4616     423.5329    6289.3264
#  C2     765.1077   21376.2641    3174.7205   18415.3655    4626.8189
#  C3   37269.4199   19089.0816   10322.7213   45118.7884    9509.1123
#  C4  174053.0129    4852.7060    1837.1512    1929.9063   18559.9079
#  C5   42950.0629  353543.3214   23533.1660  142141.0458   58800.8037
#  CH   84701.7330   37095.3240  140209.5277   64695.3692    6613.1388
#  FZ     511.5041    3603.6740    1384.3662     261.7989    5407.3605
#  GZ  103134.0791  208997.1327   44401.1352  116599.1819  117845.7820
#  HZ   13294.5009   36323.4013   13915.3957   24729.0319  161124.8102
#  IZ     827.4542    4411.5151    1775.3158    1083.1289   13093.1575
#  JZ    4584.3589   16864.9146    6538.3273   18047.6729  119286.4573
#  KZ    9394.8464   19549.4297   10587.2425   15482.4621   91068.3023
#  LZ    5175.3149   11732.0183    4816.4638   20731.6338  206425.7745
#  MN   37676.4944   99102.2136   38445.6554   87178.0547  377830.0757
#  OQ    2259.5006   15654.7141    4703.0171    6631.8377   38207.6354
#  RU     392.3209    1871.5781     703.4154    1969.3890   13619.8124
#
#               HZ           IZ           JZ           KZ           LZ  \
#  AZ     127.2736    1186.8534     187.0099      18.3496      98.8901
#  BZ   17650.3375   24542.2158    6458.2553    5947.6183   78366.9564
#  C1     802.5802   47502.7076     196.9782      24.2935     116.7808
#  C2   67315.2606    1796.1324    1124.7100    6807.6624    3923.6179
#  C3    3352.9048    1405.1190   18130.8606    1438.1681    1231.9324
#  C4   10993.2591     434.7586    1550.6693      99.6792     100.8959
#  C5   13669.1771   17573.0860   26950.5066   10876.4349   18594.8714
#  CH    5158.3776    2679.4412   10347.5056     767.8251    3900.8953
#  FZ    7290.6412    2126.5846    2348.8729    5497.0578  121488.8321
#  GZ   51502.0513   42380.8417   43530.1984   14879.4182   23423.5184
#  HZ  132143.9701   12042.0702   23662.3345   22848.7470   13400.3248
#  IZ   11866.6428   11800.5575   14970.7044   21116.1546   30333.0720
#  JZ   13891.1834   27505.0216  231340.3597   73283.2992   26721.6353
#  KZ   54430.4777   15933.6053   24319.4862  649607.8559  203815.9091
#  LZ   30246.1518   68046.4674   39581.1082   88290.1881  120172.1045
#  MN   92851.5454  119319.0326  232236.2576  208384.8475  177197.8888
#  OQ   12239.4174   12488.9839   14927.8033   26168.7032   32240.7837
#  RU    4504.9296    5283.7229   25616.9007    8623.6587    6712.5185
#
#               MN           OQ          RU
#  AZ    1671.2007    4494.1679    677.8217
#  BZ   19060.8209   70287.3581   7736.2424
#  C1    4337.8953   64683.5139   6151.4877
#  C2    5871.4107   59386.7583   2041.8304
#  C3   16143.8851   22300.4090   3209.5607
#  C4    7505.5545   31888.4242    842.5361
#  C5   50807.0545  144933.1860  12207.1558
#  CH    8254.8030   13426.8719   1809.9801
#  FZ    1904.7860   80949.6018   3911.2186
#  GZ   67567.4319  188306.4991  16619.6551
#  HZ   48140.0354   87566.3767  10903.1615
#  IZ   44476.9699   58947.1103   6385.3303
#  JZ  151133.1403  189159.8713  22341.5200
#  KZ  118609.1096  193003.2118  34478.2969
#  LZ  117487.5136  202454.9856  64075.4900
#  MN  420132.4501  400168.6666  58779.8590
#  OQ   27103.7036  132735.6330  14331.5296
#  RU   17760.5387   27382.6003  21074.8644  ,
#  '2016':             AZ          BZ           C1           C2          C3           C4  \
#  AZ  69584.7343    107.4500  171863.6520      19.3178      0.8508       0.9133
#  BZ   4919.7165  73559.2754    9059.1085  132524.7073   4637.3504    4011.1067
#  C1  33554.0137    131.0696  133856.5275     536.8786    234.8297     262.5231
#  C2   5454.9516  15610.6369    2485.0658   11014.2505   1981.3355     671.3473
#  C3   3293.2855  12364.0537    4317.2710     188.3884  49560.7383   33397.5763
#  C4    682.9146   2077.0455    2124.8123      45.8865   9902.2504  167382.6977
#  C5  25123.5820  13562.5808   46238.2409   10421.2821  23957.2481   41653.2363
#  CH   1585.9662   8429.4341   13369.4539     476.6234  53599.8731   82659.1724
#  FZ   1663.5356  13632.6533    1056.1226    8932.6894    729.2873     566.7032
#  GZ  53505.6346  25285.8041  143905.1929   10715.7703  59073.5409  102211.2809
#  HZ  11637.1370  23636.9665   28369.3514   22975.4888   9028.9149   12491.8691
#  IZ    772.0225   4785.3743    1407.3014     202.5584    888.5594     805.8962
#  JZ   1778.5189  14970.2766    6757.9605     856.8022   7324.2278    4584.9092
#  KZ   6909.6666  35182.7704    8313.2946    2161.2111   8385.0729    9272.6865
#  LZ   9480.5342   8475.1061    2830.4546     244.6044   5674.3991    5228.0859
#  MN   7775.4906  86872.4788   36423.0182   12511.8510  55402.8175   38962.2518
#  OQ   4481.5270  27673.8211    6013.0348    2442.6921   2319.2083    2247.0445
#  RU    468.8314   1481.2264     856.5044     112.1332    384.6446     375.4567
#
#               C5           CH           FZ           GZ           HZ  \
#  AZ   22702.6718       1.8050    2312.6033    3019.1546     113.0273
#  BZ   46784.8509   25034.2584   21116.7714   40348.1901   17109.8490
#  C1    7443.3632     207.8034     451.1912    6395.1249     675.4680
#  C2   17913.7175    2724.3951   17948.2339    4164.4936   58067.6650
#  C3   18733.0620    9787.6328   47928.9252    9959.2941    3161.2999
#  C4    4650.6963    1718.7319    1943.8499   20683.5380   11934.1961
#  C5  335238.8235   22151.2057  151779.3032   59124.5725   13805.2091
#  CH   34326.7027  126345.4606   66808.3681    6538.2444    5023.5069
#  FZ    3948.3829    1465.5545     294.0157    5829.0251    7175.3225
#  GZ  200171.2024   42388.6975  124958.0170  122633.3353   51123.9503
#  HZ   35418.4258   13612.2610   26990.0446  169675.2224  134643.2112
#  IZ    4248.8437    1740.8755    1151.3044   13657.5008    9242.1433
#  JZ   16658.9102    6692.1349   20715.4277  128345.0843   14053.1374
#  KZ   19113.0286   10248.5866   17386.8902   93982.7775   54675.2953
#  LZ   12363.1705    4984.8264   25300.1160  223751.7631   33039.9094
#  MN  103585.1779   39327.6313  102178.0442  384349.5297   94679.3776
#  OQ   15826.0687    4564.1689    7409.2074   38476.9483   12354.6586
#  RU    1795.2341     658.0602    2271.3618   13751.8668    4575.6950
#
#               IZ           JZ           KZ           LZ           MN  \
#  AZ    1206.5954     163.9599      14.1693      83.2207    1718.8971
#  BZ   22724.3206    6758.7980    5546.6009   81879.2115   18616.8233
#  C1   45794.9613     215.0504      24.3699     113.4329    4759.2663
#  C2    1743.2458    1086.4686    6396.0965    3800.5580    5451.1339
#  C3    1297.5535   18026.2599    1303.0187    1170.5429   15918.8624
#  C4     441.1812    1520.6382      90.7554      83.8997    8730.4826
#  C5   17596.9254   27832.7916   10612.8159   19103.8480   53631.4065
#  CH    2756.7957   10238.5360     689.4051    3479.9849    8460.8442
#  FZ    2414.0271    2435.9786    5456.0073  124505.8932    2112.2319
#  GZ   43206.8784   46632.3574   14800.6835   24960.4110   69969.6012
#  HZ   12436.3175   23329.2189   19486.4290   15140.1913   50724.1305
#  IZ   13494.2727   15285.1008   19994.3709   36061.5492   47957.9012
#  JZ   31801.3190  255141.7189   72438.1350   30659.4198  165578.7249
#  KZ   16958.3430   25143.1218  654616.3944  227403.0116  120702.1328
#  LZ   76505.4538   41972.8138   91998.5620  122642.7015  124962.4980
#  MN  123680.2788  240425.0110  197499.1708  207915.6595  451306.1379
#  OQ   12821.8102   15669.4832   26539.6790   35099.9883   28144.2906
#  RU    5546.7106   26969.2453    8657.7671    7267.0874   18414.3606
#
#               OQ          RU
#  AZ    4077.9802    670.9619
#  BZ   72395.9782   8852.9378
#  C1   67196.2691   6212.8744
#  C2   52757.8458   1820.4886
#  C3   22766.6248   3373.5298
#  C4   31443.1213   1110.5075
#  C5  142736.0791  13104.6395
#  CH   13448.3699   2077.9484
#  FZ   83976.2230   4211.7700
#  GZ  192496.2502  17733.2209
#  HZ   90183.2822  11607.4579
#  IZ   65025.5135   6760.6220
#  JZ  200940.6388  24256.6311
#  KZ  211834.6901  38435.5098
#  LZ  209693.1883  66228.7418
#  MN  430375.8984  60728.0980
#  OQ  141372.8404  14859.5395
#  RU   28592.4671  21339.5728  ,
#  '2017':             AZ          BZ           C1           C2          C3           C4  \
#  AZ  77342.0437    131.1069  174331.7773      21.1612      0.7854       0.8284
#  BZ   4866.6392  84920.4813    8564.5316  156684.3707   4010.9356    3672.1081
#  C1  32900.5667     76.8573  122182.7940     446.3947    105.0563     141.6599
#  C2   7463.0110  23274.7267    2597.2379    7894.4397   2202.1049     961.8733
#  C3   3316.2320  14108.9778    3648.8754     134.6547  47168.4414   36026.9748
#  C4    699.3179   2232.3977    1810.9472      34.9792   9112.2282  167139.7141
#  C5  24116.2744  15691.5633   46665.5210    9977.4008  22167.2236   40054.1367
#  CH   1818.5862  11157.0056   12914.0457     450.1694  53633.9982   85657.8955
#  FZ   1661.0486  14735.9195    1159.9828    8565.2104    697.9040     677.0115
#  GZ  56257.6126  30477.3895  141150.0685   10324.3822  58310.8008  103271.6404
#  HZ  12360.4330  25142.5629   30657.4139   30645.3285  10053.1137   12812.2172
#  IZ    656.9019   4339.0246    1169.8087     178.5644    725.7729     548.3383
#  JZ   1566.9257  15859.1162    6550.8523    1704.7413   7705.6441    5890.6647
#  KZ   6362.0626  41111.6502    6697.4895    2299.6617   7022.3580    7525.0674
#  LZ   8274.4402   7803.3963    3120.8556     234.5128   5681.7690    4886.8310
#  MN   6914.9530  90953.2972   41540.1387   16934.0147  63903.4487   45692.1101
#  OQ   4518.1980  27044.6838    5819.0119    2957.8420   2171.5400    2111.9854
#  RU    415.9864   1513.4631     801.9110     125.9143    352.3264     344.0528
#
#               C5           CH           FZ           GZ           HZ  \
#  AZ   22340.0168       1.7553    2244.7402    3407.1603     132.9921
#  BZ   46389.7933   23371.9460   21248.7536   46024.8182   19048.1923
#  C1    6477.8679      99.2528     224.6734    6544.9487     963.6802
#  C2   26500.9894    2577.1443   22081.3663    6652.8552   64535.5600
#  C3   17835.1614    8132.2424   49622.2452   11628.0239    2891.7367
#  C4    3958.0405    1344.3186    2024.6525   24893.0806   13056.7699
#  C5  334472.6224   19987.1075  163410.5606   73601.0619   14602.3462
#  CH   33928.0404  132884.0017   71546.1578    7820.0860    5380.8029
#  FZ    4007.7565    1524.3067     272.6438    6999.0530    7113.2198
#  GZ  202137.1361   42943.6256  134579.6641  145003.1969   54097.8168
#  HZ   50375.8887   14872.4038   28202.6077  158116.9183  141110.9932
#  IZ    3427.8314    1434.1447     985.3715   14377.4988   14092.1494
#  JZ   19254.9165    9266.0525   17552.1956  137027.4153   16163.2844
#  KZ   15615.0372    8437.0307   16149.8794   99969.3189   63216.1596
#  LZ   11381.0153    4346.5741   20995.5403  235408.2064   33600.5578
#  MN  106251.6449   45889.3713   89690.8022  417146.7789   99150.6855
#  OQ   15732.7592    4346.8134    6704.0743   40961.1536   12917.1303
#  RU    1714.5072     642.8961    1840.4436   15152.5924    4564.0912
#
#               IZ           JZ           KZ           LZ           MN  \
#  AZ    1645.5759     179.8970      18.3470      88.3083    1973.2977
#  BZ   24241.2935    6938.9549    7358.5996   86507.8412   20848.6014
#  C1   50243.9801     183.5171      18.1068      58.4825    4441.3902
#  C2    2755.4328    1718.6575    9336.2514    4592.4392    7502.7060
#  C3    1381.4271   20246.0559    1786.0128    1132.6810   17034.7893
#  C4     543.5300    1344.1546     105.6619      57.5368    8924.8127
#  C5   20305.7119   29217.5025   11956.0145   17373.1290   56122.2655
#  CH    3371.5995   10787.3116     822.0465    3228.8759    9145.8676
#  FZ    2701.8738    2509.3807    5597.2224  127694.7356    2401.8031
#  GZ   49221.3854   50285.3705   18483.4462   24958.9853   75594.4801
#  HZ   11760.4669   25458.9122   22136.0021   15887.9433   57459.2656
#  IZ   13374.0554   16385.0638   24494.9045   36083.2051   53115.8943
#  JZ   31404.9798  260676.0385   79475.7927   30516.2858  181635.8954
#  KZ   16540.1084   26852.8891  710501.1445  230642.2092  129436.1924
#  LZ   76092.6989   43670.8305   96669.9434  127490.9186  129277.6071
#  MN  131587.9852  255070.6414  232057.8053  210620.1568  468193.7731
#  OQ   13201.7153   15763.9301   28532.2807   35985.8579   31118.2394
#  RU    5622.5313   27515.0696   10729.4169    7597.5161   20190.7773
#
#               OQ          RU
#  AZ    4756.6752    781.3920
#  BZ   76534.6168   8805.8701
#  C1   67280.5669   6959.2892
#  C2   72234.3517   2537.3489
#  C3   27900.4038   4616.9222
#  C4   39339.4416   1829.4235
#  C5  143047.8435  13494.4022
#  CH   13641.5238   2370.3470
#  FZ   88010.7187   4604.1135
#  GZ  204884.8177  19911.0644
#  HZ   93439.6420  11868.8913
#  IZ   65670.4682   7200.3960
#  JZ  196114.5527  25139.8099
#  KZ  220524.4108  37087.5116
#  LZ  217850.5178  66608.5069
#  MN  425388.3897  59443.1658
#  OQ  145296.7279  16329.3493
#  RU   29126.3323  23346.5470  ,
#  '2018':             AZ           BZ           C1           C2          C3  \
#  AZ  77558.3514     146.6311  173879.6981      17.1324      0.6741
#  BZ   4771.6704  114516.8942    9152.9885  201165.4987   4391.2679
#  C1  32762.9497     100.3123  120329.2193     446.1065    143.4983
#  C2   8627.5449   35571.2351    3166.5424    9199.4549   2810.0564
#  C3   3719.5725   16665.1114    4172.6534     166.5472  52970.3538
#  C4    674.0484    2630.2213    2124.1768      41.1754  10112.3938
#  C5  24439.7241   17935.1863   52089.5332    9808.8006  23792.0689
#  CH   1829.5802   15201.5512   14183.3332     480.5709  59821.0931
#  FZ   1554.3817   13509.2730    1091.4859    7762.9253    672.6951
#  GZ  56060.1821   37333.0710  142116.6491   11501.8254  63978.7514
#  HZ  12181.6788   30122.3618   30910.3242   37652.7393  10358.8490
#  IZ    585.6415    4974.9436    1351.9600     308.5523    856.5073
#  JZ   1437.5844   20360.1797    7026.9715    2125.9804   8137.5325
#  KZ   5533.5495   52424.6017    7760.4671    2620.7041   8013.1132
#  LZ   7443.2803    9442.7769    3837.6786     211.6878   7261.0376
#  MN   6239.6931  109163.1215   42142.7366   19105.7174  67215.7708
#  OQ   4367.1770   31513.3695    6026.2415    3079.1922   2333.8277
#  RU    359.6513    1487.5445     821.4211     169.3288    378.4169
#
#               C4           C5           CH           FZ           GZ  \
#  AZ       0.6299   21898.2356       1.4363    2361.0027    3695.3354
#  BZ    4025.2635   48750.3004   24938.5249   23473.7049   52256.2707
#  C1     177.7881    6264.9732     133.3926     294.0623    6870.1397
#  C2    1080.2508   30228.1537    3155.5937   27509.5539    8991.1444
#  C3   39005.0731   19593.3507    9520.0375   50819.2379   12862.2210
#  C4  172659.1445    4479.5398    1648.3141    2052.7658   24775.7105
#  C5   42433.2192  346870.8102   22081.7796  166477.3920   78373.4618
#  CH   91831.1723   37369.4731  154674.6231   76234.0576    8980.2149
#  FZ     562.5875    3623.3945    1436.6858     248.6628    6781.6195
#  GZ  109228.5248  210287.3507   48435.9727  139534.9138  152273.8859
#  HZ   13502.6491   53900.7418   16704.3053   29291.9162  163929.9865
#  IZ     590.1375    3898.4217    1680.3747     981.0597   15167.2593
#  JZ    5756.4618   21396.0467   10493.5998   17380.9350  152463.9439
#  KZ    7684.7745   17416.8350    9530.6458   16581.7407  104227.2108
#  LZ    4982.2091   12880.7182    5148.0760   22059.3745  259057.4230
#  MN   43697.2995  110383.5995   50025.9595   88874.9155  444131.1932
#  OQ    2086.2391   16335.0564    4602.3478    6821.8025   43794.2735
#  RU     342.9542    1783.4795     691.6621    1641.5639   15877.6170
#
#               HZ           IZ           JZ           KZ           LZ  \
#  AZ     103.3270    1345.5542     157.5567      16.3777      66.4608
#  BZ   20439.6599   27655.0275    6608.0218    7976.9384   96522.3146
#  C1    1270.8656   49813.5306     194.8156      22.2762      70.8837
#  C2   74352.7737    3814.7180    2387.0747   12080.2722    6546.6677
#  C3    3241.2969    1585.8805   22963.8665    1825.6769    1489.3727
#  C4   12221.6399     598.0287    1366.8746     114.5804      63.0068
#  C5   15346.1921   21956.6843   31221.2223   12048.7774   21987.4847
#  CH    5850.5414    3770.5580   11291.8219     886.6208    4520.3494
#  FZ    6996.4440    2532.4066    2457.7975    5810.1052  132781.2323
#  GZ   57069.2443   50997.2625   53935.0683   20109.6352   28108.6413
#  HZ  155281.6264   12142.9545   29957.1817   24335.4681   17436.8977
#  IZ   17870.8010   13840.4186   18089.5082   26263.7863   35472.3797
#  JZ   19707.4908   34797.8185  280680.6446   83471.4859   31064.4716
#  KZ   73701.5494   16914.5326   30161.2952  734809.7374  230150.8340
#  LZ   34218.5200   85966.2248   43359.1067  111532.7710  129140.7761
#  MN  114138.1681  139610.1491  280915.9125  241085.5821  222657.9510
#  OQ   13994.1122   14285.1876   16399.4329   28292.8746   37794.2104
#  RU    4396.8632    5736.0267   28665.3983   10975.7582    7553.3390
#
#               MN           OQ          RU
#  AZ    2486.2966    5017.8454    787.5358
#  BZ   22530.0262   83281.7440   8641.2359
#  C1    4133.8226   66519.5095   7545.7980
#  C2   10283.7010   97035.3376   3296.9272
#  C3   18998.2176   30897.2264   4737.0052
#  C4    9460.2918   45223.1000   1872.4040
#  C5   60330.6141  143580.4671  15476.8269
#  CH   10175.6687   14798.5298   2195.0989
#  FZ    2195.8431   92421.6198   4175.1893
#  GZ   80784.1568  214517.9805  21288.7131
#  HZ   64425.5876  100983.4089  13251.5193
#  IZ   55882.4789   68681.4512   7656.2560
#  JZ  194355.0575  205392.9698  25378.7417
#  KZ  137655.9667  235283.1614  40602.5618
#  LZ  135631.8137  228747.6209  65712.9520
#  MN  499444.3059  440236.9182  62704.4659
#  OQ   33281.7614  145788.7598  17803.6448
#  RU   20915.7835   26438.4031  24573.1350  ,
#  '2019':             AZ           BZ           C1           C2          C3  \
#  AZ  76327.6172     137.0547  174839.8254      15.0813      0.4963
#  BZ   4847.7120  107347.3244    8485.4141  180013.9283   4169.0695
#  C1  33347.4166     101.0618  124719.0355     347.0509    141.7553
#  C2   7569.3809   26856.3813    2504.1156    7762.2770   2522.1717
#  C3   3458.5537   16206.9948    4173.0585     151.8613  52268.2300
#  C4    674.5858    2512.8923    1905.5583      35.0687  10494.4633
#  C5  24862.8408   17467.9086   47974.4249    8635.9539  22477.7717
#  CH   1854.3058   14132.1675   14058.1857     433.5318  60587.1714
#  FZ   1644.3388   12501.6045    1088.7850    7038.9661    654.2733
#  GZ  57942.1962   36077.4630  144584.1511   11452.8728  64034.8736
#  HZ  12221.6379   29999.1170   31002.0315   37336.6041  10722.0593
#  IZ    608.5917    4894.3048    1308.5779     312.5367    876.8131
#  JZ   1530.6189   20537.5897    6818.8562    2241.3961   8686.4518
#  KZ   5762.9494   51464.0643    7379.6637    2381.9960   8446.2018
#  LZ   7913.8762   11003.4780    3956.0838     175.6365   7689.7548
#  MN   6771.1872  116742.8536   41662.2289   21829.7443  72716.6680
#  OQ   4384.0812   30918.1337    5966.2450    3230.5951   2336.6177
#  RU    367.6250    1510.8472     828.4192     186.9178    392.8576
#
#               C4           C5           CH           FZ           GZ  \
#  AZ       0.4824   19888.6032       1.0598    2146.3638    3415.4279
#  BZ    3711.4682   45002.5241   21494.7096   24508.1727   47094.5144
#  C1     173.4637    5997.5669     130.7460     305.4593    6900.7696
#  C2     836.8915   23591.6182    2448.5233   23543.0250    6749.0571
#  C3   36670.4037   20421.0333    9542.8779   50380.6200   12161.1912
#  C4  180494.9042    4217.0721    1609.1361    1859.9156   23488.0544
#  C5   41455.4071  317365.0947   20860.0686  169197.4541   74194.4480
#  CH   89766.0832   37477.9718  146750.5092   78431.5077    8535.5767
#  FZ     579.3003    3696.0740    1415.7802     248.6009    6552.4561
#  GZ  108003.5376  206050.7387   48317.8944  143215.4070  151863.2307
#  HZ   13470.4218   54344.4878   16301.9489   29996.6598  162559.0296
#  IZ     676.2750    3841.7568    1689.1962     975.0221   14229.7213
#  JZ    5037.4835   21283.7173   10675.5446   18360.9923  147293.7249
#  KZ    9572.8952   17711.8551    9922.5624   15805.3036   99899.6737
#  LZ    3983.7662   14464.3542    5347.4565   28490.6734  302464.5968
#  MN   42663.0750  115404.2385   51863.4492   93129.5547  445034.7330
#  OQ    2008.6128   15970.4229    4290.7721    7014.0610   43320.5425
#  RU     354.1586    1802.7333     700.6507    1833.1798   15405.5916
#
#               HZ           IZ           JZ           KZ           LZ  \
#  AZ     124.9250    1331.1561     158.9237      12.3600      42.7044
#  BZ   17870.0620   25550.3605    6791.2633    6578.6915  113889.0502
#  C1    1416.6158   49598.3537     210.0454      19.3766      75.3137
#  C2   67339.5469    2774.7929    1952.3461    9534.7435    6808.5750
#  C3    3466.8079    1305.1727   21793.3981    1943.4755    1581.9692
#  C4   11763.4345     560.9013    1153.7910      97.3473      44.9871
#  C5   15610.8952   21478.6476   32574.1086   11013.5856   23035.0802
#  CH    6176.2297    3633.4151   11173.4556     823.9728    5251.2492
#  FZ    6758.4179    2513.1323    2658.8593    6106.4160  134221.7019
#  GZ   58538.9066   51030.2304   56043.1092   19120.1227   30293.1437
#  HZ  158849.6290   11935.0220   31809.9582   22246.7602   21694.6378
#  IZ   20542.2416   13298.7583   17801.5562   23153.3313   43217.2338
#  JZ   20163.3356   35267.1134  290701.5229   75804.8168   35010.3569
#  KZ   74821.7436   17148.6198   30310.3694  753348.2524  258969.0964
#  LZ   38051.2409  103576.8800   52772.1100  121552.7476  133292.5668
#  MN  122288.4119  144121.0850  288722.8374  228203.4748  266588.8005
#  OQ   14168.4075   14234.5791   16616.1310   27659.9522   43396.8689
#  RU    4537.2610    5755.5087   30128.2907   10674.8939    8855.8534
#
#               MN           OQ          RU
#  AZ    2669.0472    4872.0861    755.9499
#  BZ   22594.9471   86998.3872   8584.0125
#  C1    4581.5579   69478.5893   7465.8119
#  C2    9307.3364   87406.3315   2623.7814
#  C3   18746.2161   31578.4860   4787.0990
#  C4   10116.7348   44405.9399   1400.4743
#  C5   65333.8398  146177.7800  14403.3916
#  CH   11321.3050   15626.7926   2277.0189
#  FZ    2373.4222   96748.9894   4260.8448
#  GZ   87911.2243  225587.8378  20819.9253
#  HZ   71388.4387  109706.9269  13869.9698
#  IZ   58189.4183   70860.3118   7620.4236
#  JZ  209945.9280  222099.1242  26355.6682
#  KZ  144835.1299  259472.8482  42702.1069
#  LZ  156633.6059  242884.2171  70682.0135
#  MN  554063.3895  485611.0952  66307.0815
#  OQ   35208.3801  149818.6039  17988.0295
#  RU   22523.6503   28770.9289  25655.1306  ,
#  '2020':             AZ          BZ           C1           C2          C3           C4  \
#  AZ  78131.5556     94.8418  174342.3299       9.1854      0.6168       0.6065
#  BZ   5305.7526  89524.1015    8511.0019  102322.9156   3141.6857    3180.1779
#  C1  34109.6369     89.5135  126588.3955     240.3843    127.3722     150.0006
#  C2   5126.9403  13735.9027    1880.1343    2308.1782   1497.5436     509.9164
#  C3   3571.7263  12889.2723    4270.6964     126.9073  49260.9766   32487.8076
#  C4    659.4662   1800.3830    1799.9698      18.5722   8506.3181  141529.4485
#  C5  25505.4251  13338.7995   47513.5718    4735.6626  19144.2586   38841.3409
#  CH   1865.6877  10134.1742   13322.8306     245.6786  49569.1047   72880.7273
#  FZ   2004.6165  10940.5553    1773.3514    4788.8027    819.5770     762.4080
#  GZ  61485.9221  30214.8047  150401.7568    7071.5906  62032.0752   98929.2543
#  HZ  12283.4477  28413.4570   30450.4900   26007.5489  10563.4371   12047.4549
#  IZ    457.9297   2727.9162    1042.9143     208.9552    513.6036     386.7390
#  JZ   1601.6729  15094.1313    8981.7946    1411.9889   7494.7766    3953.9020
#  KZ   5854.2027  36505.8601    7940.2889    1909.0297   7978.2532    7839.6457
#  LZ   8945.1390   9502.3309    4333.1825     125.4703   6994.1790    3522.3897
#  MN   7093.6732  86180.5367   45178.3650   10638.9846  73956.7800   40113.7710
#  OQ   4385.8667  26894.6953    5636.1032    1659.9882   1866.5311    1616.5626
#  RU    318.5735   1000.1161     761.8871     100.1833    303.6450     288.7931
#
#               C5           CH           FZ           GZ           HZ  \
#  AZ   22233.9896       1.2969    2601.4149    3108.0935     109.2465
#  BZ   37221.7046   18478.2706   27056.3323   48151.8894   16486.6494
#  C1    6367.2312     123.9499     306.7753    5967.0774     894.2868
#  C2   13108.0553    1534.8850   16183.8013    3924.6866   31566.4534
#  C3   21041.5626    9400.1477   52368.3047   13614.4239    3011.9032
#  C4    3650.1358    1438.2179    1825.3348   22082.7845    8736.3156
#  C5  286483.2228   19158.1288  177398.4933   73933.9586   13682.7196
#  CH   32927.8127  124227.8510   78677.3633    8059.1441    4197.4759
#  FZ    5198.2507    1783.5415     485.1032    9639.6415    6372.0372
#  GZ  199504.3107   47059.9513  155888.8063  161766.7883   43406.5687
#  HZ   53423.0024   15178.5656   31698.5588  164518.2221  158094.4893
#  IZ    2407.5869     884.6380     696.2876    9149.7797   13342.4237
#  JZ   19816.4577    9560.2704   20373.5012  155827.1530   20661.5552
#  KZ   16576.0815    8275.2828   19921.6520   90564.8301   64533.3542
#  LZ   15435.5706    6182.9878   34387.9923  294480.4735   32817.9953
#  MN  105939.3042   44992.4736  135608.4334  424630.9116  111710.1165
#  OQ   13663.1546    3374.8814    8356.8844   40932.8034   11081.0845
#  RU    1438.8784     520.1980    1719.2608   12595.4638    3675.5849
#
#               IZ           JZ           KZ           LZ           MN  \
#  AZ    1107.9431     111.0251      17.7747      48.5586    2164.3712
#  BZ   20042.1673    6954.4019    7141.3754  101698.9727   23772.7169
#  C1   41090.1310     258.4968      19.0094      67.4330    4430.0320
#  C2    1308.7027    1316.6255    5928.5328    3589.6220    6016.6236
#  C3    1113.6083   23383.8296    1634.4933    1429.8354   19180.7057
#  C4     399.4744     995.9240      86.4434      33.6544    8429.3351
#  C5   16479.1477   31824.9822   10323.2927   18439.6983   61323.2257
#  CH    2894.7087   10163.7937     743.2811    3541.8297   10091.5016
#  FZ    2794.0392    2890.9532    5280.2393  130291.7121    3112.9655
#  GZ   43723.5085   61268.0688   19881.0332   27241.1021   90484.2286
#  HZ    8086.2244   35101.4104   18474.6267   13271.4348   71728.7333
#  IZ    5108.2904   13653.3639   17080.2646   33609.4012   44062.6656
#  JZ   27681.6701  307109.2538   75145.7945   35160.6152  221438.4019
#  KZ   12554.5190   37863.5939  799537.0052  275044.8490  163905.1130
#  LZ   87223.8809   43861.7156  102720.4837  137051.5221  140210.9187
#  MN  108436.9795  322338.4418  243432.3216  269682.2003  585293.3756
#  OQ   10794.1122   15248.5334   27262.1706   41168.2319   33719.1908
#  RU    3423.0200   16502.4600    9593.3588    7238.6067   19534.0752
#
#               OQ          RU
#  AZ    5190.0919    680.9927
#  BZ   84423.5746   7768.4504
#  C1   63220.8259   4342.8080
#  C2   46778.9917   1529.1873
#  C3   33450.8908   4860.8524
#  C4   51137.9366   1067.5064
#  C5  137865.5737  12740.1783
#  CH   14632.9329   2349.2494
#  FZ  100927.5156   6837.4512
#  GZ  223042.0431  18047.3744
#  HZ   99777.0076   9622.2255
#  IZ   50700.5554   3956.8585
#  JZ  220647.1349  20057.4732
#  KZ  272902.1457  37653.3455
#  LZ  224626.5454  64124.7385
#  MN  467755.3042  49900.7584
#  OQ  158788.5179  15506.8593
#  RU   29709.8928  15773.5852  }
